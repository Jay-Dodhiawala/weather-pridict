# %%
import numpy as np
import pandas as pd

# %%
weather = pd.read_csv('weather.csv', index_col="DATE")

# %%
weather
# Out:
#                 STATION                                        NAME  PRCP  \
# DATE
# 1960-01-01  CA005023222  WINNIPEG RICHARDSON INTERNATIONAL A, MB CA  0.15
# 1960-01-02  CA005023222  WINNIPEG RICHARDSON INTERNATIONAL A, MB CA  0.00
# 1960-01-03  CA005023222  WINNIPEG RICHARDSON INTERNATIONAL A, MB CA  0.00
# 1960-01-04  CA005023222  WINNIPEG RICHARDSON INTERNATIONAL A, MB CA  0.00
# 1960-01-05  CA005023222  WINNIPEG RICHARDSON INTERNATIONAL A, MB CA  0.00
# ...                 ...                                         ...   ...
# 2008-07-20  CA005023222  WINNIPEG RICHARDSON INTERNATIONAL A, MB CA  0.12
# 2008-07-21  CA005023222  WINNIPEG RICHARDSON INTERNATIONAL A, MB CA  0.00
# 2008-07-22  CA005023222  WINNIPEG RICHARDSON INTERNATIONAL A, MB CA  0.00
# 2008-07-23  CA005023222  WINNIPEG RICHARDSON INTERNATIONAL A, MB CA  0.12
# 2008-07-24  CA005023222  WINNIPEG RICHARDSON INTERNATIONAL A, MB CA  0.00
#
#             SNOW  SNWD  TMAX  TMIN
# DATE
# ...

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# PRCP       0.001019
# SNOW       0.019701
# SNWD       0.060519
# TMAX       0.000113
# TMIN       0.000057
# dtype: float64

# %%
core_weather = weather[["PRCP", "SNOW", "SNWD", "TMAX", "TMIN"]]

# %%
core_weather.columns=["precip", "snow", "snow_depth", "temp_max", "temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1960-01-01    0.15   1.5         1.2      19.0      13.0
# 1960-01-02    0.00   0.0         2.0       9.0      -1.0
# 1960-01-03    0.00   0.0         2.0     -12.0     -18.0
# 1960-01-04    0.00   0.0         2.0      -9.0     -21.0
# 1960-01-05    0.00   0.0         2.0      -6.0     -22.0
# ...            ...   ...         ...       ...       ...
# 2008-07-20    0.12   NaN         NaN      76.0      55.0
# 2008-07-21    0.00   NaN         NaN      78.0      52.0
# 2008-07-22    0.00   NaN         NaN      81.0      59.0
# 2008-07-23    0.12   NaN         NaN      75.0      64.0
# 2008-07-24    0.00   NaN         NaN      82.0      66.0
#
# [17664 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip        0.001019
# snow          0.019701
# snow_depth    0.060519
# temp_max      0.000113
# temp_min      0.000057
# dtype: float64

# %%
core_weather["snow_depth"].value_counts()
# Out:
# 0.0     10940
# 1.2       373
# 5.1       340
# 3.9       326
# 2.0       300
#         ...
# 23.6        4
# 23.2        3
# 15.4        2
# 29.9        2
# 33.1        1
# Name: snow_depth, Length: 68, dtype: int64

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 2005-01-01     NaN   NaN         NaN       4.0     -13.0
# 2005-01-08     NaN   NaN         NaN       8.0     -11.0
# 2006-10-10     NaN   NaN         0.0      47.0      25.0
# 2006-10-11     NaN   NaN         NaN      34.0      22.0
# 2006-10-12     NaN   NaN         NaN      40.0      26.0
# 2006-10-29     NaN   NaN         NaN      33.0      18.0
# 2006-10-30     NaN   NaN         NaN      31.0      24.0
# 2006-10-31     NaN   NaN         NaN      27.0      22.0
# 2007-01-01     NaN   NaN         NaN      15.0      -4.0
# 2007-01-03     NaN   NaN         NaN      42.0      20.0
# 2007-03-18     NaN   NaN         NaN      34.0      27.0
# 2007-03-28     NaN   0.0         NaN      44.0      36.0
# 2007-03-29     NaN   NaN         NaN      39.0      27.0
# 2007-03-30     NaN   NaN         NaN      45.0      23.0
# 2007-04-01     NaN   NaN         NaN      37.0      28.0
# ...

# %%
core_weather.loc["2006-10-01": "2006-10-15", :]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 2006-10-01     0.0   0.0         0.0      79.0      44.0
# 2006-10-02     0.0   0.0         0.0      68.0      41.0
# 2006-10-03     0.0   0.0         0.0      56.0      31.0
# 2006-10-04     0.0   0.0         0.0      59.0      27.0
# 2006-10-05     0.0   0.0         0.0      66.0      37.0
# 2006-10-06     0.0   0.0         0.0      65.0      49.0
# 2006-10-07     0.0   0.0         0.0      74.0      53.0
# 2006-10-08     0.0   0.0         0.0      58.0      25.0
# 2006-10-09     0.0   0.0         0.0      53.0      31.0
# 2006-10-10     NaN   NaN         0.0      47.0      25.0
# 2006-10-11     NaN   NaN         NaN      34.0      22.0
# 2006-10-12     NaN   NaN         NaN      40.0      26.0
# 2006-10-13     0.0   0.0         NaN      41.0      29.0
# 2006-10-14     0.0   0.0         NaN      45.0      23.0
# 2006-10-15     0.0   0.0         NaN      50.0      23.0

# %%
core_weather["precip"] = core_weather["precip"].fillna(0)
# Out:
# C:\Users\jaydo\AppData\Local\Temp\ipykernel_17064\671213293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   core_weather["precip"] = core_weather["precip"].fillna(0)

# %%
core_weather[pd.isnull(core_weather["snow"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 2002-10-05    0.16   NaN         0.0      44.0      23.0
# 2002-10-17    0.01   NaN         0.0      37.0      20.0
# 2002-10-18    0.06   NaN         0.0      39.0      22.0
# 2002-10-27    0.02   NaN         0.0      35.0      19.0
# 2002-10-28    0.26   NaN         0.0      33.0      27.0
# ...            ...   ...         ...       ...       ...
# 2008-07-20    0.12   NaN         NaN      76.0      55.0
# 2008-07-21    0.00   NaN         NaN      78.0      52.0
# 2008-07-22    0.00   NaN         NaN      81.0      59.0
# 2008-07-23    0.12   NaN         NaN      75.0      64.0
# 2008-07-24    0.00   NaN         NaN      82.0      66.0
#
# [348 rows x 5 columns]

# %%
core_weather["snow"] = core_weather["snow"].fillna(0)
# Out:
# C:\Users\jaydo\AppData\Local\Temp\ipykernel_17064\3311520555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   core_weather["snow"] = core_weather["snow"].fillna(0)

# %%
core_weather[pd.isnull(core_weather["snow_depth"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 2003-01-01    0.00   0.0         NaN      18.0      10.0
# 2003-01-02    0.02   0.0         NaN      24.0      16.0
# 2003-01-03    0.02   0.0         NaN      29.0      21.0
# 2003-01-04    0.00   0.0         NaN      28.0      21.0
# 2003-01-05    0.00   0.0         NaN      22.0      16.0
# ...            ...   ...         ...       ...       ...
# 2008-07-20    0.12   0.0         NaN      76.0      55.0
# 2008-07-21    0.00   0.0         NaN      78.0      52.0
# 2008-07-22    0.00   0.0         NaN      81.0      59.0
# 2008-07-23    0.12   0.0         NaN      75.0      64.0
# 2008-07-24    0.00   0.0         NaN      82.0      66.0
#
# [1069 rows x 5 columns]

# %%
core_weather.loc["2002-12-25": "2003-01-30", :]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 2002-12-25    0.00   0.0         4.7      19.0      -1.0
# 2002-12-26    0.00   0.0         4.7      21.0       3.0
# 2002-12-27    0.00   0.0         4.7      31.0      11.0
# 2002-12-28    0.00   0.0         4.7      22.0      -2.0
# 2002-12-29    0.02   0.0         4.7      30.0      17.0
# 2002-12-30    0.04   0.0         4.7      31.0       4.0
# 2002-12-31    0.00   0.0         3.9      11.0       1.0
# 2003-01-01    0.00   0.0         NaN      18.0      10.0
# 2003-01-02    0.02   0.0         NaN      24.0      16.0
# 2003-01-03    0.02   0.0         NaN      29.0      21.0
# 2003-01-04    0.00   0.0         NaN      28.0      21.0
# 2003-01-05    0.00   0.0         NaN      22.0      16.0
# 2003-01-06    0.00   0.0         NaN      35.0      14.0
# 2003-01-07    0.02   0.0         NaN      43.0      30.0
# 2003-01-08    0.00   0.0         NaN      41.0      23.0
# ...

# %%
core_weather = core_weather.fillna(method="ffill")

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip        0.0
# snow          0.0
# snow_depth    0.0
# temp_max      0.0
# temp_min      0.0
# dtype: float64

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04',
#                '1960-01-05', '1960-01-06', '1960-01-07', '1960-01-08',
#                '1960-01-09', '1960-01-10',
#                ...
#                '2008-07-15', '2008-07-16', '2008-07-17', '2008-07-18',
#                '2008-07-19', '2008-07-20', '2008-07-21', '2008-07-22',
#                '2008-07-23', '2008-07-24'],
#               dtype='datetime64[ns]', name='DATE', length=17664, freq=None)

# %%
core_weather.apply(lambda x:(x==9999).sum())
# Out:
# precip        0
# snow          0
# snow_depth    0
# temp_max      0
# temp_min      0
# dtype: int64

# %%
core_weather[["temp_max", "temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["target"] = core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target
# DATE
# 1960-01-01    0.15   1.5         1.2      19.0      13.0     9.0
# 1960-01-02    0.00   0.0         2.0       9.0      -1.0   -12.0
# 1960-01-03    0.00   0.0         2.0     -12.0     -18.0    -9.0
# 1960-01-04    0.00   0.0         2.0      -9.0     -21.0    -6.0
# 1960-01-05    0.00   0.0         2.0      -6.0     -22.0     6.0
# ...            ...   ...         ...       ...       ...     ...
# 2008-07-20    0.12   0.0         0.0      76.0      55.0    78.0
# 2008-07-21    0.00   0.0         0.0      78.0      52.0    81.0
# 2008-07-22    0.00   0.0         0.0      81.0      59.0    75.0
# 2008-07-23    0.12   0.0         0.0      75.0      64.0    82.0
# 2008-07-24    0.00   0.0         0.0      82.0      66.0     NaN
#
# [17664 rows x 6 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target
# DATE
# 1960-01-01    0.15   1.5         1.2      19.0      13.0     9.0
# 1960-01-02    0.00   0.0         2.0       9.0      -1.0   -12.0
# 1960-01-03    0.00   0.0         2.0     -12.0     -18.0    -9.0
# 1960-01-04    0.00   0.0         2.0      -9.0     -21.0    -6.0
# 1960-01-05    0.00   0.0         2.0      -6.0     -22.0     6.0
# ...            ...   ...         ...       ...       ...     ...
# 2008-07-19    0.00   0.0         0.0      78.0      55.0    76.0
# 2008-07-20    0.12   0.0         0.0      76.0      55.0    78.0
# 2008-07-21    0.00   0.0         0.0      78.0      52.0    81.0
# 2008-07-22    0.00   0.0         0.0      81.0      59.0    75.0
# 2008-07-23    0.12   0.0         0.0      75.0      64.0    82.0
#
# [17663 rows x 6 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["precip", "snow", "snow_depth", "temp_max", "temp_min"]

# %%
train = core_weather.loc[:"2006-12-31"]
test = core_weather.loc["2007-01-01":]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"], predictions)
# Out:
# 6.81427676867933

# %%
combine = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)

# %%
combine
# Out:
#             target          0
# DATE
# 2007-01-01    26.0  17.767012
# 2007-01-02    42.0  23.261314
# 2007-01-03    37.0  42.804269
# 2007-01-04    32.0  40.288509
# 2007-01-05    25.0  35.129944
# ...            ...        ...
# 2008-07-19    76.0  76.627745
# 2008-07-20    78.0  74.817927
# 2008-07-21    81.0  76.187278
# 2008-07-22    75.0  79.605426
# 2008-07-23    82.0  75.342532
#
# [568 rows x 2 columns]

# %%
combine.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-1.80186902, -2.11574659, -0.15151562,  0.79679696,  0.14682245])

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2006-12-31"]
    test = core_weather.loc["2007-01-01":]
    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])
    error = mean_absolute_error(test["target"], predictions)
    combine = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combine.columns["actual", "predictions"]
    return error, combine

# %%
core_weather.corr()["target"]
# Out:
# precip        0.096988
# snow         -0.227418
# snow_depth   -0.590215
# temp_max      0.948060
# temp_min      0.917019
# target        1.000000
# Name: target, dtype: float64

# %%
import numpy as np
test = pd.Series([["prec", "snow", "snow_d", "tempMax", "tempMin"],[ 0, 0, 0, -2, -10]], )
test
# predictions = reg.predict(test)
# Out:
# 0    [prec, snow, snow_d, tempMax, tempMin]
# 1                        [0, 0, 0, -2, -10]
# dtype: object
